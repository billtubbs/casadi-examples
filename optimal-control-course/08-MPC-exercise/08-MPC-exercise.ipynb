# %% [markdown]
# # Model Predictive Control

# %%
import os
import time
import numpy as np
from numpy.testing import assert_array_equal, assert_array_almost_equal
import matplotlib.pyplot as plt
from casadi import MX, DM, Function, Opti
import casadi as cas
from platform import python_version

print(f"Casadi: {cas.__version__}")
print(f"Python: {python_version()}")
# Out:
# Casadi: 3.6.7
# Python: 3.10.16

# %%
plot_dir = 'plots'
if not os.path.exists(plot_dir):
    os.mkdir(plot_dir)

# %% [markdown]
# ## Cart-pole System

# %% [markdown]
# Inverted pendulum on a horizontally-constrained cart:
#
# <img src='images/cart_pend_diagram.png' width=300>
#
# The system is controlled by a force acting in the x-direction on the cart. The system is described by a four-dimensional state-space:
#
# $$ x = \left[\begin{matrix} p \\ \theta \\ \dot{p} \\ \dot{\theta} \end{matrix}\right]$$

# %%
# Physical constants
g = 9.81     # gravitation [m/s^2]
L = 0.2      # pendulum length [m]
m = 1        # pendulum mass [kg]
mcart = 0.5  # cart mass [kg]

T = 2.0  # control horizon [s]
N = 160  # Number of control intervals
dt = T/N  # length of 1 control interval [s]

# System is composed of 4 states
nx = 4

# %%
# CasADi function for the ODE right-hand side
xk = MX.sym('x', nx)  # states: pos [m], theta [rad], dpos [m/s], dtheta [rad/s]
uk = MX.sym('u')  # control force [N]
ddpos = (
    (uk + m * L * xk[3] * xk[3] * cas.sin(xk[1]) - m * g * cas.sin(xk[1]) * cas.cos(xk[1]))
    / (mcart + m - m * cas.cos(xk[1]) * cas.cos(xk[1]))
)
rhs = cas.vertcat(xk[2], xk[3], ddpos, g/L * cas.sin(xk[1]) - cas.cos(xk[1]) * ddpos)

# Continuous-time system dynamics
f = Function('f', [xk, uk], [rhs], ['xk', 'uk'], ['dxdt'])
f
# Out:
# Function(f:(xk[4],uk)->(dxdt[4]) MXFunction)

# %%
# Discrete-time system dynamics
intg_options = {'number_of_finite_elements': 1}

# Reference Runge-Kutta implementation
solver = 'rk'
dae = {'x': xk, 'p': uk, 'ode': f(xk, uk)}
t0 = 0
tf = dt / intg_options['number_of_finite_elements']
intg = cas.integrator('intg', solver, dae, t0, tf, intg_options)
print(intg)
res = intg(x0=xk, p=uk)
xf = res['xf']

# Discretized system dynamics
F = Function('F', [xk, uk], [xf], ['xk', 'uk'], ['xkp1'])
F
# Out:
# intg:(x0[4],z0[0],p,u[0],adj_xf[],adj_zf[],adj_qf[])->(xf[4],zf[0],qf[0],adj_x0[],adj_z0[],adj_p[],adj_u[]) RungeKutta
# Function(F:(xk[4],uk)->(xkp1[4]) MXFunction)

# %% [markdown]
# ## Reference optimal control using multiple shooting

# %% [markdown]
# Optimal control problem using multiple shooting
#
# $$
# \begin{aligned}
# \underset{x_1,x_2,...,x_{N+1},u_1,u_2,...,u_N}{\text{minimize}} \quad & \sum_{k=1}^{N}{u_k^2} \\
# \text{subject to} \quad & F(x_k,u_k) = x_{k+1}, \quad k=1, ..., N \\
#                   & -3 \le x_k \le 3, \quad k=1, ..., N+1 \\
#                   & -1.2 \le u_k \le 1.2, \quad k=1, ..., N \\
#                   & x_1 = \left[\begin{matrix}1 & 0 & 0 & 0\end{matrix}\right]^T \\
#                   & x_{N+1} = \left[\begin{matrix}0 & 0 & 0 & 0\end{matrix}\right]^T \\
# \end{aligned}
# $$

# %%
opti = cas.Opti()

# Decision variables for states
X = opti.variable(nx, N+1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:,k],U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3,  pos, 3)) # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == cas.vertcat(1, 0, 0, 0))
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls
opti.minimize(cas.sumsqr(U))

# solve optimization problem
opti.solver('ipopt')

sol = opti.solve()
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     3048
# Number of nonzeros in inequality constraint Jacobian.:      321
# Number of nonzeros in Lagrangian Hessian.............:      960
#
# Total number of variables............................:      804
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      648
# Total number of inequality constraints...............:      321
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:      321
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.9558430e+01 2.79e-01 7.93e-01  -1.0 1.65e+00    -  4.32e-01 7.21e-01h  1
#    2  1.1896518e+02 6.06e-02 1.17e-01  -1.0 4.27e-01    -  9.33e-01 7.83e-01h  1
#    3  1.3627244e+02 8.85e-07 1.38e-03  -1.7 1.40e-01    -  1.00e+00 1.00e+00h  1
#    4  1.3571014e+02 9.09e-08 4.38e-02  -2.5 5.44e-02    -  9.36e-01 1.00e+00f  1
#    5  1.3546206e+02 2.84e-08 1.46e-04  -2.5 2.94e-02    -  1.00e+00 1.00e+00f  1
#    6  1.3531355e+02 9.56e-09 3.61e-03  -3.8 1.62e-02    -  9.60e-01 1.00e+00f  1
#    7  1.3528680e+02 5.99e-10 7.54e-06  -3.8 8.73e-03    -  1.00e+00 1.00e+00f  1
#    8  1.3527675e+02 2.05e-10 1.10e-04  -5.7 5.81e-03    -  9.93e-01 1.00e+00f  1
#    9  1.3527625e+02 3.58e-11 1.06e-07  -5.7 2.78e-03    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.3527611e+02 2.73e-12 9.30e-08  -8.6 8.65e-04    -  1.00e+00 1.00e+00f  1
#   11  1.3527611e+02 2.49e-14 3.13e-11  -8.6 8.71e-05    -  1.00e+00 1.00e+00h  1
#   12  1.3527611e+02 2.22e-16 6.25e-13  -9.0 9.62e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.3527610574433854e+02    1.3527610574433854e+02
# Dual infeasibility......:   6.2527760746888816e-13    6.2527760746888816e-13
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.1107572160358007e-10    9.1107572160358007e-10
# Overall NLP error.......:   9.1107572160358007e-10    9.1107572160358007e-10
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 0.455
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  33.00us (  2.54us)  30.06us (  2.31us)        13
#        nlp_g  |  13.78ms (  1.06ms)  13.79ms (  1.06ms)        13
#   nlp_grad_f  |  99.00us (  7.07us)  95.94us (  6.85us)        14
#   nlp_hess_l  | 222.85ms ( 18.57ms) 250.55ms ( 20.88ms)        12
#    nlp_jac_g  | 109.62ms (  7.83ms) 144.63ms ( 10.33ms)        14
#        total  | 393.06ms (393.06ms) 455.86ms (455.86ms)         1

# %% [markdown]
# ## Plot functions

# %%
def make_ioplots(t, pos, theta, dpos, dtheta, u, 
                 figsize=(6, 5)):

    fig, axes = plt.subplots(3, 1, sharex=True, 
                             figsize=figsize)
    
    ax = axes[0]
    ax.plot(t, theta, label=r'$\theta$ [rad]')
    ax.plot(t, pos, label=r'$p$ [m]')
    ax.legend()
    ax.grid()
    ax.set_title('Cart position and pendulum angle')
    
    ax = axes[1]
    ax.plot(t, dtheta, label=r'$d\theta/dt$ [rad/s]')
    ax.plot(t, dpos, label=r'$dp/dt$ [m/s]')
    ax.legend()
    ax.grid()
    ax.set_title('Speed and angular velocity')
    
    ax = axes[2]
    ax.step(t[:-1], u, label=r'$F$ [N]')
    ax.set_xlabel('Time [s]')
    ax.legend()
    ax.grid()
    ax.set_title('Horizontal force applied to cart')

    plt.tight_layout()

pos_opt = sol.value(pos)
theta_opt = sol.value(theta)
dpos_opt = sol.value(dpos)
dtheta_opt = sol.value(dtheta)
u_opt = sol.value(U)
tgrid = np.linspace(0, T, N+1)

make_ioplots(tgrid, pos_opt, theta_opt, dpos_opt, dtheta_opt, u_opt)
filename = 'mpc_solution_1_ioplot.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %%
def pend_sequence_plot(pos, theta, k_step=8, L=L, figsize=(6, 2.5)):

    cart_pos = np.stack([pos, np.zeros_like(pos)])
    end_pos = np.stack([pos + L * np.sin(theta), L * np.cos(theta)])
    N = end_pos.shape[1]

    fig, ax = plt.subplots(figsize=figsize)

    k_values = list(range(0, N, k_step))
    for k in k_values:
        if k == 0:
            style, alpha, label = ('r.-', 1, f'$k = {k}$')
        elif k == k_values[-1]:
            style, alpha, label = ('b.-', 1, f'$k = {k}$')
        else:
            style, alpha, label = ('k.-', 0.5, None)
        ax.plot([cart_pos[0, k], end_pos[0, k]], 
                [cart_pos[1, k], end_pos[1, k]], 
                style, linewidth=1, alpha=alpha, label=label)

    ax.axis('equal')
    ax.set_xlabel('x position')
    ax.set_ylabel('y position')
    ax.grid()
    ax.legend()
    ax.set_title('Cart-pendulum positions over time')

    return ax

ax = pend_sequence_plot(pos_opt, theta_opt)
plt.tight_layout()
filename = 'mpc_solution_1_seq.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %% [markdown]
# ## 1. Basic implementation of MPC

# %% [markdown]
# ### 1.1 Add a strong regularization term on the cart position

# %% [markdown]
# $$
# \begin{aligned}
# \underset{x_1,x_2,...,x_{N+1},u_1,u_2,...,u_N}{\text{minimize}} \quad & \sum_{k=1}^{N}{u_k^2} + \color{red}{1000 \sum_{k=1}^{N+1}{p_k^2}} \\
# \text{subject to} \quad & F(x_k,u_k) = x_{k+1}, \quad k=1, ..., N \\
#                   & -3 \le x_k \le 3, \quad k=1, ..., N+1 \\
#                   & -1.2 \le u_k \le 1.2, \quad k=1, ..., N \\
#                   & x_1 = \left[\begin{matrix}1 & 0 & 0 & 0\end{matrix}\right]^T \\
#                   & x_{N+1} = \left[\begin{matrix}0 & 0 & 0 & 0\end{matrix}\right]^T \\
# \end{aligned}
# $$
#
# This will promote keeping the position of the cart close to the origin.

# %%
opti = cas.Opti()

# Decision variables for states
X = opti.variable(nx, N + 1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:, k], U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3, pos, 3))  # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == cas.vertcat(1, 0, 0, 0))
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls + cart position
opti.minimize(cas.sumsqr(U) + 1000 * cas.sumsqr(pos))

opti.solver('ipopt')

# solve optimization problem
sol = opti.solve()
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     3048
# Number of nonzeros in inequality constraint Jacobian.:      321
# Number of nonzeros in Lagrangian Hessian.............:     1121
#
# Total number of variables............................:      804
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      648
# Total number of inequality constraints...............:      321
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:      321
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.3742334e+02 9.41e-01 1.03e-01  -1.0 2.00e+01    -  5.64e-02 5.95e-02h  1
#    2  2.3464411e+02 9.22e-01 1.00e+01  -1.0 1.29e+01    -  1.17e-01 1.92e-02h  1
#    3  7.3592699e+02 8.65e-01 1.88e+01  -1.0 1.06e+01    -  1.34e-01 6.27e-02h  1
#    4  1.6330730e+03 8.02e-01 2.97e+01  -1.0 9.36e+00    -  1.40e-01 7.19e-02h  1
#    5  2.5076072e+03 7.59e-01 3.99e+01  -1.0 1.21e+01    -  1.06e-01 5.41e-02h  1
#    6  3.3886715e+03 7.23e-01 4.98e+01  -1.0 1.36e+01    -  9.33e-02 4.69e-02h  1
#    7  4.2773848e+03 6.93e-01 5.91e+01  -1.0 1.42e+01    -  8.55e-02 4.26e-02h  1
#    8  5.2018425e+03 6.64e-01 6.75e+01  -1.0 1.46e+01    -  8.10e-02 4.09e-02h  1
#    9  6.1418105e+03 6.38e-01 7.51e+01  -1.0 1.48e+01    -  7.67e-02 3.91e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.0635394e+03 6.15e-01 8.22e+01  -1.0 1.49e+01    -  7.28e-02 3.65e-02h  1
#   11  8.0280554e+03 5.93e-01 8.89e+01  -1.0 1.48e+01    -  7.24e-02 3.67e-02h  1
#   12  8.9940089e+03 5.71e-01 9.48e+01  -1.0 1.48e+01    -  6.93e-02 3.56e-02h  1
#   13  1.0054971e+04 5.50e-01 9.87e+01  -1.0 1.45e+01    -  6.61e-02 3.79e-02h  1
#   14  1.1035241e+04 5.31e-01 1.03e+02  -1.0 1.45e+01    -  6.42e-02 3.43e-02h  1
#   15  1.2015622e+04 5.13e-01 1.07e+02  -1.0 1.43e+01    -  6.25e-02 3.38e-02h  1
#   16  1.3026798e+04 4.95e-01 1.11e+02  -1.0 1.42e+01    -  6.22e-02 3.44e-02h  1
#   17  1.4079337e+04 4.78e-01 1.14e+02  -1.0 1.40e+01    -  6.35e-02 3.54e-02h  1
#   18  1.5190575e+04 4.60e-01 1.17e+02  -1.0 1.38e+01    -  6.69e-02 3.70e-02h  1
#   19  1.6388944e+04 4.42e-01 1.21e+02  -1.0 1.36e+01    -  7.26e-02 3.97e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.7700649e+04 4.23e-01 1.24e+02  -1.0 1.32e+01    -  8.04e-02 4.32e-02h  1
#   21  1.9138905e+04 4.03e-01 1.28e+02  -1.0 1.27e+01    -  8.97e-02 4.73e-02h  1
#   22  2.0708093e+04 3.82e-01 1.32e+02  -1.0 1.21e+01    -  1.00e-01 5.18e-02h  1
#   23  2.2355080e+04 3.61e-01 1.37e+02  -1.0 1.15e+01    -  1.13e-01 5.48e-02h  1
#   24  2.3310851e+04 3.49e-01 1.52e+02  -1.0 1.09e+01    -  1.31e-01 3.25e-02h  1
#   25  2.5032474e+04 3.29e-01 1.65e+02  -1.0 9.55e+00    -  1.85e-01 5.85e-02h  1
#   26  2.7085300e+04 3.06e-01 1.72e+02  -1.0 8.70e+00    -  1.95e-01 7.09e-02h  1
#   27  2.9213533e+04 2.82e-01 1.58e+02  -1.0 8.36e+00    -  7.18e-02 7.56e-02h  1
#   28  3.1005532e+04 2.64e-01 1.64e+02  -1.0 8.11e+00    -  1.87e-01 6.62e-02h  1
#   29  3.3194685e+04 2.42e-01 1.57e+02  -1.0 7.81e+00    -  1.43e-01 8.34e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.5414563e+04 2.20e-01 1.43e+02  -1.0 9.03e+00    -  8.80e-02 8.87e-02h  1
#   31  3.6001882e+04 2.15e-01 1.58e+02  -1.0 7.68e+00    -  2.01e-01 2.52e-02h  1
#   32  3.8649608e+04 1.90e-01 1.46e+02  -1.0 6.32e+00    -  1.78e-01 1.13e-01h  1
#   33  4.1899823e+04 1.62e-01 1.22e+02  -1.0 7.56e+00    -  1.28e-01 1.50e-01h  1
#   34  4.2606761e+04 1.56e-01 1.34e+02  -1.0 6.12e+00    -  2.54e-01 3.73e-02h  1
#   35  4.4874399e+04 1.37e-01 1.23e+02  -1.0 4.71e+00    -  2.13e-01 1.22e-01h  1
#   36  4.8715505e+04 1.06e-01 9.43e+01  -1.0 5.75e+00    -  2.14e-01 2.26e-01h  1
#   37  4.9698794e+04 9.82e-02 8.94e+01  -1.0 4.14e+00    -  1.16e-01 7.26e-02h  1
#   38  5.1603261e+04 8.35e-02 8.27e+01  -1.7 3.70e+00    -  3.20e-01 1.49e-01h  1
#   39  5.2552859e+04 7.63e-02 7.50e+01  -1.7 3.65e+00    -  6.78e-02 8.60e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.5919583e+04 5.15e-02 5.51e+01  -1.7 3.28e+00    -  4.92e-01 3.26e-01h  1
#   41  5.6234842e+04 4.92e-02 5.33e+01  -1.7 2.45e+00    -  7.75e-02 4.44e-02h  1
#   42  5.9747350e+04 2.42e-02 2.64e+01  -1.7 2.12e+00    -  5.18e-01 5.07e-01h  1
#   43  5.9931725e+04 2.29e-02 2.85e+01  -1.7 1.52e+00    -  3.88e-01 5.31e-02h  1
#   44  6.3010612e+04 1.80e-03 2.64e+00  -1.7 1.11e+00    -  1.00e+00 9.21e-01h  1
#   45  6.3274819e+04 1.30e-08 1.74e-03  -2.5 1.54e-01    -  9.92e-01 1.00e+00h  1
#   46  6.3274441e+04 3.13e-10 6.12e-06  -3.8 1.17e-02    -  1.00e+00 1.00e+00f  1
#   47  6.3274420e+04 6.60e-12 7.08e-08  -5.7 1.62e-03    -  1.00e+00 1.00e+00f  1
#   48  6.3274420e+04 2.05e-15 1.16e-10  -8.6 2.60e-05    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 48
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3274420021677477e+04    6.3274420021677477e+04
# Dual infeasibility......:   1.1641532182693481e-10    1.1641532182693481e-10
# Constraint violation....:   2.0539125955565396e-15    2.0539125955565396e-15
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   4.3026789856651171e-09    4.3026789856651171e-09
# Overall NLP error.......:   4.3026789856651171e-09    4.3026789856651171e-09
#
#
# Number of objective function evaluations             = 49
# Number of objective gradient evaluations             = 49
# Number of equality constraint evaluations            = 49
# Number of inequality constraint evaluations          = 49
# Number of equality constraint Jacobian evaluations   = 49
# Number of inequality constraint Jacobian evaluations = 49
# Number of Lagrangian Hessian evaluations             = 48
# Total seconds in IPOPT                               = 1.542
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 158.00us (  3.22us) 144.87us (  2.96us)        49
#        nlp_g  |  52.39ms (  1.07ms)  52.54ms (  1.07ms)        49
#   nlp_grad_f  | 269.00us (  5.38us) 268.85us (  5.38us)        50
#   nlp_hess_l  | 927.25ms ( 19.32ms) 930.52ms ( 19.39ms)        48
#    nlp_jac_g  | 381.76ms (  7.64ms) 383.86ms (  7.68ms)        50
#        total  |   1.54 s (  1.54 s)   1.54 s (  1.54 s)         1

# %%
pos_opt = sol.value(pos)
theta_opt = sol.value(theta)
dpos_opt = sol.value(dpos)
dtheta_opt = sol.value(dtheta)
u_opt = sol.value(U)
tgrid = np.linspace(0, T, N+1)

make_ioplots(tgrid, pos_opt, theta_opt, dpos_opt, dtheta_opt, u_opt)
filename = 'mpc_solution_1_1_ioplot.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %%
ax = pend_sequence_plot(pos_opt, theta_opt)
plt.tight_layout()
filename = 'mpc_solution_1_1_seq.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %% [markdown]
# ### 1.2 Introduce a parameter for the initial state of the OCP
#
# This is needed so we can repeatedly solve the MPC problem at the current state, $x_k$.

# %%
opti = Opti()

# Decision variables for states
X = opti.variable(nx, N + 1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Parameter for initial state
x0 = opti.parameter(nx)

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:, k], U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3, pos, 3))  # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == x0)
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls + cart position
opti.minimize(cas.sumsqr(U) + 1000 * cas.sumsqr(pos))

opti.solver('ipopt')

# %% [markdown]
# Now we can set the parameter value and solve, then re-solve again using the following code only (don't have to recreate the problem structure as above).  The second solve and all subsequent will be fast.

# %%
# solve optimization problem
opti.set_value(x0, cas.vertcat(0.5, 0, 0, 0))
sol = opti.solve()
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     3048
# Number of nonzeros in inequality constraint Jacobian.:      321
# Number of nonzeros in Lagrangian Hessian.............:     1121
#
# Total number of variables............................:      804
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      648
# Total number of inequality constraints...............:      321
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:      321
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 5.00e-01 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.3742334e+02 4.41e-01 1.96e-01  -1.0 9.99e+00    -  1.07e-01 1.19e-01h  1
#    2  2.3969864e+02 4.22e-01 8.24e+00  -1.0 6.19e+00    -  2.19e-01 4.29e-02h  1
#    3  6.7135311e+02 3.70e-01 1.44e+01  -1.0 5.18e+00    -  2.53e-01 1.22e-01h  1
#    4  1.4308860e+03 3.14e-01 2.12e+01  -1.0 4.11e+00    -  2.89e-01 1.52e-01h  1
#    5  2.1387284e+03 2.76e-01 2.77e+01  -1.0 4.91e+00    -  2.49e-01 1.22e-01h  1
#    6  2.8394390e+03 2.45e-01 3.38e+01  -1.0 5.00e+00    -  2.44e-01 1.13e-01h  1
#    7  3.5371939e+03 2.18e-01 3.91e+01  -1.0 4.87e+00    -  2.50e-01 1.10e-01h  1
#    8  4.2374603e+03 1.94e-01 4.36e+01  -1.0 4.55e+00    -  2.68e-01 1.11e-01h  1
#    9  4.9695451e+03 1.71e-01 4.62e+01  -1.0 4.15e+00    -  2.84e-01 1.18e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.7245871e+03 1.49e-01 4.77e+01  -1.0 3.78e+00    -  3.17e-01 1.26e-01h  1
#   11  6.4648921e+03 1.30e-01 4.73e+01  -1.0 3.37e+00    -  3.23e-01 1.31e-01h  1
#   12  7.2648473e+03 1.10e-01 4.60e+01  -1.0 3.03e+00    -  3.99e-01 1.53e-01h  1
#   13  8.0931939e+03 9.07e-02 4.23e+01  -1.0 2.61e+00    -  4.20e-01 1.75e-01h  1
#   14  8.8708722e+03 7.37e-02 3.80e+01  -1.0 2.19e+00    -  4.77e-01 1.88e-01h  1
#   15  9.6749164e+03 5.70e-02 3.27e+01  -1.0 1.81e+00    -  6.16e-01 2.27e-01h  1
#   16  1.0509822e+04 4.05e-02 2.53e+01  -1.0 1.43e+00    -  7.36e-01 2.90e-01h  1
#   17  1.1211038e+04 2.71e-02 1.73e+01  -1.7 1.14e+00    -  5.26e-01 3.29e-01h  1
#   18  1.1807795e+04 1.62e-02 1.09e+01  -1.7 8.24e-01    -  8.70e-01 4.04e-01h  1
#   19  1.2445388e+04 4.80e-03 3.39e+00  -1.7 5.28e-01    -  1.00e+00 7.03e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.2718534e+04 1.60e-07 4.94e-02  -2.5 2.27e-01    -  8.84e-01 1.00e+00h  1
#   21  1.2718213e+04 8.05e-09 7.82e-04  -3.8 2.74e-02    -  9.99e-01 9.90e-01f  1
#   22  1.2718199e+04 1.42e-09 6.62e-06  -3.8 1.69e-02    -  1.00e+00 1.00e+00f  1
#   23  1.2718186e+04 2.56e-10 1.28e-06  -5.7 8.73e-03    -  1.00e+00 1.00e+00f  1
#   24  1.2718185e+04 2.68e-11 8.30e-08  -5.7 3.26e-03    -  1.00e+00 1.00e+00f  1
#   25  1.2718185e+04 8.48e-13 2.61e-09  -5.7 5.82e-04    -  1.00e+00 1.00e+00f  1
#   26  1.2718185e+04 1.61e-14 9.47e-11  -8.6 6.98e-05    -  1.00e+00 1.00e+00f  1
#   27  1.2718185e+04 1.11e-16 2.91e-11  -9.0 3.52e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 27
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2718185251541046e+04    1.2718185251541046e+04
# Dual infeasibility......:   2.9103830456733704e-11    2.9103830456733704e-11
# Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.0936111830229490e-10    9.0936111830229490e-10
# Overall NLP error.......:   9.0936111830229490e-10    9.0936111830229490e-10
#
#
# Number of objective function evaluations             = 28
# Number of objective gradient evaluations             = 28
# Number of equality constraint evaluations            = 28
# Number of inequality constraint evaluations          = 28
# Number of equality constraint Jacobian evaluations   = 28
# Number of inequality constraint Jacobian evaluations = 28
# Number of Lagrangian Hessian evaluations             = 27
# Total seconds in IPOPT                               = 0.861
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 123.00us (  4.39us) 111.83us (  3.99us)        28
#        nlp_g  |  30.47ms (  1.09ms)  30.77ms (  1.10ms)        28
#   nlp_grad_f  | 177.00us (  6.10us) 164.41us (  5.67us)        29
#   nlp_hess_l  | 506.10ms ( 18.74ms) 506.76ms ( 18.77ms)        27
#    nlp_jac_g  | 222.00ms (  7.66ms) 222.16ms (  7.66ms)        29
#        total  | 865.25ms (865.25ms) 865.97ms (865.97ms)         1

# %%
pos_opt = sol.value(pos)
theta_opt = sol.value(theta)
dpos_opt = sol.value(dpos)
dtheta_opt = sol.value(dtheta)
u_opt = sol.value(U)
tgrid = np.linspace(0, T, N+1)

make_ioplots(tgrid, pos_opt, theta_opt, dpos_opt, dtheta_opt, u_opt)
filename = 'mpc_solution_1_2_ioplot.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %%
ax = pend_sequence_plot(pos_opt, theta_opt)
plt.tight_layout()
filename = 'mpc_solution_1_2_seq.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %% [markdown]
# ### 1.3. & 1.4 Implement MPC loop for 5 sample periods and silence NLP solver output

# %%
Nsim = 5
xk = cas.vertcat(0.5, 0, 0, 0)

# Silence optimizer outputs
options = {'ipopt': {"print_level": 0}}
opti.solver('ipopt', options)

x_history = DM.zeros(nx, N)
u_history = DM.zeros(1, N)

for i in range(Nsim):

    t0 = time.time()

    # Get first control action from solver solution
    uk = sol.value(U[0])
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    # Set the value of parameter x0 to the current x
    opti.set_value(x0, xk)

    # Solve the NLP
    sol = opti.solve()

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 106.00us (  3.93us)  94.95us (  3.52us)        27
#        nlp_g  |  30.27ms (  1.12ms)  30.40ms (  1.13ms)        27
#   nlp_grad_f  | 155.00us (  5.54us) 147.17us (  5.26us)        28
#   nlp_hess_l  | 497.85ms ( 19.15ms) 498.10ms ( 19.16ms)        26
#    nlp_jac_g  | 216.01ms (  7.71ms) 216.74ms (  7.74ms)        28
#        total  | 844.11ms (844.11ms) 845.66ms (845.66ms)         1
# 0: 0.97397 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 103.00us (  3.81us)  92.18us (  3.41us)        27
#        nlp_g  |  30.04ms (  1.11ms)  30.04ms (  1.11ms)        27
#   nlp_grad_f  | 175.00us (  6.25us) 155.86us (  5.57us)        28
#   nlp_hess_l  | 497.75ms ( 19.14ms) 498.49ms ( 19.17ms)        26
#    nlp_jac_g  | 217.94ms (  7.78ms) 218.63ms (  7.81ms)        28
#        total  | 849.72ms (849.72ms) 851.36ms (851.36ms)         1
# 1: 0.85294 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  99.00us (  3.67us)  88.69us (  3.28us)        27
#        nlp_g  |  28.77ms (  1.07ms)  28.59ms (  1.06ms)        27
#   nlp_grad_f  | 185.00us (  6.61us) 170.50us (  6.09us)        28
#   nlp_hess_l  | 493.55ms ( 18.98ms) 494.36ms ( 19.01ms)        26
#    nlp_jac_g  | 213.11ms (  7.61ms) 213.07ms (  7.61ms)        28
#        total  | 836.23ms (836.23ms) 837.30ms (837.30ms)         1
# 2: 0.83866 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  93.00us (  3.32us) 104.02us (  3.72us)        28
#        nlp_g  |  30.16ms (  1.08ms)  30.55ms (  1.09ms)        28
#   nlp_grad_f  | 150.00us (  5.17us) 141.04us (  4.86us)        29
#   nlp_hess_l  | 512.05ms ( 18.96ms) 512.72ms ( 18.99ms)        27
#    nlp_jac_g  | 218.67ms (  7.54ms) 218.59ms (  7.54ms)        29
#        total  | 862.87ms (862.87ms) 864.02ms (864.02ms)         1
# 3: 0.86553 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  82.00us (  3.04us)  79.44us (  2.94us)        27
#        nlp_g  |  28.13ms (  1.04ms)  28.08ms (  1.04ms)        27
#   nlp_grad_f  | 144.00us (  5.14us) 135.82us (  4.85us)        28
#   nlp_hess_l  | 489.12ms ( 18.81ms) 490.03ms ( 18.85ms)        26
#    nlp_jac_g  | 208.54ms (  7.45ms) 209.08ms (  7.47ms)        28
#        total  | 823.34ms (823.34ms) 825.21ms (825.21ms)         1
# 4: 0.82717 seconds

# %% [markdown]
# Each MPC iteration takes about 0.9 seconds

# %% [markdown]
# ## 2. Speeding up the implementation

# %% [markdown]
# ### 2.1. Hot-starting

# %%
Nsim = 5
xk = cas.vertcat(0.5, 0, 0, 0)

# Silence optimizer outputs
options = {'ipopt': {"print_level": 0}}
opti.solver('ipopt', options)

opti.set_value(x0, xk)
sol = opti.solve()

x_history = DM.zeros(nx, N)
u_history = DM.zeros(1, N)

for i in range(Nsim):

    t0 = time.time()

    # Get first control action from solver solution
    uk = sol.value(U[0])
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    # Set the value of parameter x0 to the current x
    opti.set_value(x0, xk)

    # Hot-start the optimization with solution from previous iteration
    opti.set_initial(opti.x, sol.value(opti.x))  # primal variables
    opti.set_initial(opti.lam_g, sol.value(opti.lam_g))  # dual variables

    # Solve the NLP
    sol = opti.solve()

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  93.00us (  3.32us)  84.35us (  3.01us)        28
#        nlp_g  |  30.05ms (  1.07ms)  30.04ms (  1.07ms)        28
#   nlp_grad_f  | 162.00us (  5.59us) 150.56us (  5.19us)        29
#   nlp_hess_l  | 519.90ms ( 19.26ms) 639.20ms ( 23.67ms)        27
#    nlp_jac_g  | 222.97ms (  7.69ms) 224.60ms (  7.74ms)        29
#        total  | 876.90ms (876.90ms) 997.95ms (997.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  62.00us (  4.43us)  51.75us (  3.70us)        14
#        nlp_g  |  16.16ms (  1.15ms)  16.26ms (  1.16ms)        14
#   nlp_grad_f  |  93.00us (  6.20us)  85.16us (  5.68us)        15
#   nlp_hess_l  | 243.05ms ( 18.70ms) 243.66ms ( 18.74ms)        13
#    nlp_jac_g  | 122.37ms (  8.16ms) 122.45ms (  8.16ms)        15
#        total  | 439.78ms (439.78ms) 440.85ms (440.85ms)         1
# 0: 0.45125 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  54.00us (  3.60us)  49.69us (  3.31us)        15
#        nlp_g  |  16.21ms (  1.08ms)  16.14ms (  1.08ms)        15
#   nlp_grad_f  | 112.00us (  7.00us) 104.10us (  6.51us)        16
#   nlp_hess_l  | 264.84ms ( 18.92ms) 272.62ms ( 19.47ms)        14
#    nlp_jac_g  | 120.98ms (  7.56ms) 121.52ms (  7.60ms)        16
#        total  | 463.43ms (463.43ms) 472.87ms (472.87ms)         1
# 1: 0.47954 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  48.00us (  3.20us)  46.69us (  3.11us)        15
#        nlp_g  |  15.88ms (  1.06ms)  15.88ms (  1.06ms)        15
#   nlp_grad_f  |  86.00us (  5.38us)  80.83us (  5.05us)        16
#   nlp_hess_l  | 259.57ms ( 18.54ms) 300.21ms ( 21.44ms)        14
#    nlp_jac_g  | 120.57ms (  7.54ms) 126.73ms (  7.92ms)        16
#        total  | 455.77ms (455.77ms) 513.12ms (513.12ms)         1
# 2: 0.51917 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  47.00us (  3.13us)  41.58us (  2.77us)        15
#        nlp_g  |  15.46ms (  1.03ms)  15.51ms (  1.03ms)        15
#   nlp_grad_f  |  80.00us (  5.00us)  75.54us (  4.72us)        16
#   nlp_hess_l  | 254.51ms ( 18.18ms) 254.76ms ( 18.20ms)        14
#    nlp_jac_g  | 119.51ms (  7.47ms) 119.78ms (  7.49ms)        16
#        total  | 445.88ms (445.88ms) 446.48ms (446.48ms)         1
# 3: 0.45258 seconds
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  52.00us (  3.47us)  47.53us (  3.17us)        15
#        nlp_g  |  15.87ms (  1.06ms)  15.92ms (  1.06ms)        15
#   nlp_grad_f  |  78.00us (  4.88us)  73.29us (  4.58us)        16
#   nlp_hess_l  | 259.44ms ( 18.53ms) 260.44ms ( 18.60ms)        14
#    nlp_jac_g  | 120.42ms (  7.53ms) 120.93ms (  7.56ms)        16
#        total  | 454.70ms (454.70ms) 456.49ms (456.49ms)         1
# 4: 0.46252 seconds

# %% [markdown]
# Each MPC iteration takes around 0.5 seconds.
#
# Interior point methods approximate the 1st order optimality conditions using a relaxed constraint (a smooth one) and then progressively increase the angle.  So the previous solution won't work well at the beginning of the next iteration.

# %% [markdown]
# ### 2.2 Try SQP method

# %% [markdown]
# This is a 'text book' QP method built into CasADi (uses a sparse QP solver written by Andersson who wrote CasADi).

# %%
opti = Opti()

# Decision variables for states
X = opti.variable(nx, N + 1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Parameter for initial state
x0 = opti.parameter(nx)

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:, k], U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3, pos, 3))  # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == x0)
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls + cart position
opti.minimize(cas.sumsqr(U) + 1000 * cas.sumsqr(pos))

# %%
Nsim = 5
xk = cas.vertcat(0.5, 0, 0, 0)

options = {'qpsol': 'qrqp'}
# Silence optimizer outputs
options["qpsol_options"] = {"print_iter": False, "print_header": False}
options["print_iteration"] = False
options["print_header"] = False
options["print_status"] = False
options["print_time"] = False
opti.solver('sqpmethod', options)

opti.set_value(x0, xk)
sol = opti.solve()

x_history = DM.zeros(nx, N)
u_history = DM.zeros(1, N)

for i in range(Nsim):

    t0 = time.time()

    # Get first control action from solver solution
    uk = sol.value(U[0])
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    # Set the value of parameter x0 to the current x
    opti.set_value(x0, xk)

    # Hot-start the optimization with solution from previous iteration
    opti.set_initial(opti.x, sol.value(opti.x))  # primal variables
    opti.set_initial(opti.lam_g, sol.value(opti.lam_g))  # dual variables

    # Solve the NLP
    sol = opti.solve()

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
# 0: 0.10531 seconds
# 1: 0.10534 seconds
# 2: 0.10378 seconds
# 3: 0.10886 seconds
# 4: 0.10761 seconds

# %% [markdown]
# Each MPC iteration takes about 0.1 seconds

# %% [markdown]
# ## 2.3 Code inlining and matrix expansion

# %%
# CasADi function for the ODE right-hand side
xk = MX.sym('x',nx) # states: pos [m], theta [rad], dpos [m/s], dtheta [rad/s]
uk = MX.sym('u') # control force [N]

# Discrete-time system dynamics
intg_options = {'number_of_finite_elements': 1}
intg_options['simplify'] = 1

# Reference Runge-Kutta implementation
solver = 'rk'
dae = {'x': xk, 'p': uk, 'ode': f(xk, uk)}
t0 = 0
tf = dt / intg_options['number_of_finite_elements']
intg = cas.integrator('intg', solver, dae, t0, tf, intg_options)
print(intg)
res = intg(x0=xk, p=uk)
xf = res['xf']

# Discretized system dynamics
F = Function('F', [xk, uk], [xf], ['xk', 'uk'], ['xkp1'])
F
# Out:
# intg:(x0[4],z0[0],p,u[0],adj_xf[],adj_zf[],adj_qf[])->(xf[4],zf[],qf[0],adj_x0[],adj_z0[],adj_p[],adj_u[]) MXFunction
# Function(F:(xk[4],uk)->(xkp1[4]) MXFunction)

# %%
opti = Opti()

# Decision variables for states
X = opti.variable(nx, N + 1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Parameter for initial state
x0 = opti.parameter(nx)

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:, k], U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3, pos, 3))  # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == x0)
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls + cart position
opti.minimize(cas.sumsqr(U) + 1000 * cas.sumsqr(pos))

# %%
Nsim = 5
xk = cas.vertcat(0.5, 0, 0, 0)

options = {'qpsol': 'qrqp'}
# Silence optimizer outputs
options["qpsol_options"] = {"print_iter": False, "print_header": False}
options["print_iteration"] = False
options["print_header"] = False
options["print_status"] = False
options["print_time"] = False
opti.solver('sqpmethod', options)

opti.set_value(x0, xk)
sol = opti.solve()

x_history = DM.zeros(nx, N)
u_history = DM.zeros(1, N)

for i in range(Nsim):

    t0 = time.time()

    # Get first control action from solver solution
    uk = sol.value(U[0])
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    # Set the value of parameter x0 to the current x
    opti.set_value(x0, xk)

    # Hot-start the optimization with solution from previous iteration
    opti.set_initial(opti.x, sol.value(opti.x))  # primal variables
    opti.set_initial(opti.lam_g, sol.value(opti.lam_g))  # dual variables

    # Solve the NLP
    sol = opti.solve()

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
# 0: 0.07634 seconds
# 1: 0.07694 seconds
# 2: 0.07822 seconds
# 3: 0.07674 seconds
# 4: 0.08262 seconds

# %% [markdown]
# Each MPC iteration takes about 0.08 seconds

# %%
xk = cas.vertcat(0.5, 0, 0, 0)

options = {'qpsol': 'qrqp'}
# Silence optimizer outputs
options["qpsol_options"] = {"print_iter": False, "print_header": False}
options["print_iteration"] = False
options["print_header"] = False
options["print_status"] = False
options["print_time"] = False
options["expand"] = True  # makes function evaluations faster but requires more memory
opti.solver('sqpmethod', options)

opti.set_value(x0, xk)
sol = opti.solve()

Nsim = 5
x_history = DM.zeros(nx, Nsim)
u_history = DM.zeros(1, Nsim)

for i in range(Nsim):

    t0 = time.time()

    # Get first control action from solver solution
    uk = sol.value(U[0])
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    # Set the value of parameter x0 to the current x
    opti.set_value(x0, xk)

    # Hot-start the optimization with solution from previous iteration
    opti.set_initial(opti.x, sol.value(opti.x))  # primal variables
    opti.set_initial(opti.lam_g, sol.value(opti.lam_g))  # dual variables

    # Solve the NLP
    sol = opti.solve()

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
# 0: 0.01264 seconds
# 1: 0.01277 seconds
# 2: 0.01366 seconds
# 3: 0.01290 seconds
# 4: 0.01805 seconds

# %% [markdown]
# Each MPC iteration takes about 0.02 seconds

# %% [markdown]
# ### 2.4 Convert into regular CasADi function

# %%
opti = Opti()

# Decision variables for states
X = opti.variable(nx, N + 1)

# Aliases for states
pos    = X[0, :]
theta  = X[1, :]
dpos   = X[2, :]
dtheta = X[3, :]

# Decision variables for control actions
U = opti.variable(N, 1)  # force [N]

# Parameter for initial state
x0 = opti.parameter(nx)

# Gap-closing shooting constraints
for k in range(N):
    opti.subject_to(X[:, k+1] == F(X[:, k], U[k]))

# Path constraints
opti.subject_to(opti.bounded(-3, pos, 3))  # Syntax -3 <= pos <= 3 not supported in Python
opti.subject_to(opti.bounded(-1.2, U, 1.2))

# Initial and terminal constraints
opti.subject_to(X[:, 0] == x0)
opti.subject_to(X[:, -1] == cas.vertcat(0, 0, 0, 0))

# Objective: regularization of controls + cart position
opti.minimize(cas.sumsqr(U) + 1000 * cas.sumsqr(pos))

# %%
xk = cas.vertcat(0.5, 0, 0, 0)

options = {'qpsol': 'qrqp'}
# Silence optimizer outputs
options["qpsol_options"] = {"print_iter": False, "print_header": False}
options["print_iteration"] = False
options["print_header"] = False
options["print_status"] = False
options["print_time"] = False
options["expand"] = True  # makes function evaluations faster but requires more memory
opti.solver('sqpmethod', options)

opti.set_value(x0, xk)
sol = opti.solve()

# %%
inputs = {'x0': x0, 'x': opti.x, 'lam_g': opti.lam_g}
outputs = {'U[0]': U[0], 'x': opti.x, 'lam_g': opti.lam_g}
options = {'allow_duplicate_io_names': 1}
mpc_step = opti.to_function('mpc_step', inputs.values(), outputs.values(), inputs.keys(), outputs.keys(), options)
mpc_step
# Out:
# Function(mpc_step:(x0[4],x[804],lam_g[969])->(U[0],x[804],lam_g[969]) MXFunction)

# %%
Nsim = 5
x_history = DM.zeros(nx, Nsim)
u_history = DM.zeros(1, Nsim)

xk = cas.vertcat(0.5, 0, 0, 0)
opti.set_value(x0, xk)
sol = opti.solve()

uk = sol.value(U[0])
x, lam_g = sol.value(opti.x), sol.value(opti.lam_g)

for i in range(Nsim):

    t0 = time.time()

    # Save first control action from solver solution
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    uk, x, lam_g = mpc_step(xk, x, lam_g)

    print(f"{i}: {time.time() - t0:.5f} seconds")
# Out:
# 0: 0.00760 seconds
# 1: 0.05047 seconds
# 2: 0.03360 seconds
# 3: 0.02293 seconds
# 4: 0.00871 seconds

# %% [markdown]
# Each MPC iteration takes about 0.01 seconds

# %% [markdown]
# Note: A further speed improvement might be possible using codegeneration. Since CasADi 3.5, you can generate C-code for `sqpmethod` and
# `qrqp` QP solver routines.

# %% [markdown]
# ## 3. Analyzing the control performance

# %% [markdown]
# ### 3.1 Extend simulation to 200 time steps

# %%
Nsim = 200
x_history = DM.zeros(nx, Nsim)
u_history = DM.zeros(1, Nsim)
mpc_exec_times = np.full(Nsim, np.nan)

xk = cas.vertcat(0.5, 0, 0, 0)
opti.set_value(x0, xk)
sol = opti.solve()
uk = sol.value(U[0])
x, lam_g = sol.value(opti.x), sol.value(opti.lam_g)

for i in range(Nsim):

    # Save first control action from solver solution
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk)
    x_history[:, i] = xk

    t0 = time.time()
    uk, x, lam_g = mpc_step(xk, x, lam_g)
    mpc_exec_times[i] = time.time() - t0

print(f"Avg. elapsed time per iteration: {np.mean(mpc_exec_times) * 1000:.2f} ms")
# Out:
# Avg. elapsed time per iteration: 4.54 ms

# %%
plt.figure(figsize=(7, 2))
plt.hist(mpc_exec_times * 1000, bins=21)
plt.xlabel('Execution time (ms)')
plt.ylabel('Frequency')
plt.title('Distribution of MPC execution times')
plt.grid()
plt.show()

# %%
tgrid = dt * np.arange(Nsim)
pos = np.array(x_history[0, :]).reshape(-1)
theta = np.array(x_history[1, :]).reshape(-1)
dpos = np.array(x_history[2, :]).reshape(-1)
dtheta = np.array(x_history[3, :]).reshape(-1)
u = np.array(u_history[:-1]).reshape(-1)
make_ioplots(tgrid, pos, theta, dpos, dtheta, u)
filename = 'mpc_solution_3_1_ioplot.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %%
# Root-mean-squared tracking error in system states
x_rmse = np.sqrt(np.mean(np.array(x_history) ** 2))
x_rmse
# Out:
# 0.22939975412928276

# %% [markdown]
# The system regulated towards $[0, 0, 0, 0]^T$ as mandated by the terminal constraint, which is at the end of the prediction horizon.

# %% [markdown]
# Time at step $k = 161$ (the end of the prediction horizon at $t = 0$)

# %%
k = 161
t = k * dt
t
# Out:
# 2.0125

# %%
xk = np.array(x_history[:, k]).reshape(-1)
xk
# Out:
# array([ 0.00028846, -0.00029674, -0.00063332,  0.00195251])

# %% [markdown]
# The reason it does not actually reach zero at $k = 161$ is that we only implement the first control action of the solver's optimal solution at $t = 0$.  After that, the prediction horizon is shifted ahead in time and so the terminal constraint is also further ahead.

# %% [markdown]
# ### 3.2 Add a random disturbance to the system

# %%
Nsim = 400

# Random process disturbance
k_noise_start = Nsim // 2
W = DM(np.stack([
    np.zeros(Nsim), 
    np.zeros(Nsim), 
    np.zeros(Nsim), 
    np.concatenate([np.zeros(k_noise_start), 0.01 * np.random.rand(Nsim - k_noise_start)])
]))
assert W.shape == (4, Nsim)

x_history = DM.zeros(nx, Nsim)
u_history = DM.zeros(1, Nsim)
mpc_exec_times = np.full(Nsim, np.nan)

xk = cas.vertcat(0.5, 0, 0, 0)
opti.set_value(x0, xk)
sol = opti.solve()
uk = sol.value(U[0])
x, lam_g = sol.value(opti.x), sol.value(opti.lam_g)

for i in range(Nsim):

    # Save first control action from solver solution
    u_history[:, i] = uk

    # Simulate the system over dt
    xk = F(xk, uk) + W[:, i]
    x_history[:, i] = xk

    t0 = time.time()
    uk, x, lam_g = mpc_step(xk, x, lam_g)
    mpc_exec_times[i] = time.time() - t0

print(f"Avg. elapsed time per iteration: {np.mean(mpc_exec_times) * 1000:.2f} ms")
# Out:
# Avg. elapsed time per iteration: 4.17 ms

# %%
tgrid = dt * np.arange(Nsim)
pos = np.array(x_history[0, :]).reshape(-1)
theta = np.array(x_history[1, :]).reshape(-1)
dpos = np.array(x_history[2, :]).reshape(-1)
dtheta = np.array(x_history[3, :]).reshape(-1)
u = np.array(u_history[:-1]).reshape(-1)
make_ioplots(tgrid, pos, theta, dpos, dtheta, u)
filename = 'mpc_solution_3_2_ioplot.pdf'
plt.savefig(os.path.join(plot_dir, filename))
plt.show()

# %%
# Root-mean-squared tracking error in system states
x_rmse = np.sqrt(np.mean(np.array(x_history) ** 2))
x_rmse
# Out:
# 0.16395934825863703

# %% [markdown]
# When the random disturbance is applied to the states of the simulated system, the MPC is unable to get the system to the $[0, 0, 0, 0]^T$ state.  If you look at the position $p$ in the plot above, there is a steady-state error (or offset).

# %% [markdown]
# A well-tuned PID controller would be able to compensate for the steady-state error because it has an integrator action.

# %% [markdown]
# To achieve offset-free control with MPC you need to design the system model (augment the state-space model) to allow for the disturbance and use an estimator to estimate it in real time.
